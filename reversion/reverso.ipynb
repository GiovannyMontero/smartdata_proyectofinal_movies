-- %%
%python
dbutils.widgets.removeAll()

-- %%
%python
dbutils.widgets.text("storageLocation","azmedallonlakehouse")
dbutils.widgets.text("catalogo","databricks_course_ws")

-- %%
%python

storageLocation = dbutils.widgets.get("storageLocation")
catalogo = dbutils.widgets.get("catalogo")

rutaRaw = f"abfss://raw@{storageLocation}.dfs.core.windows.net"
rutaBronze = f"abfss://bronze@{storageLocation}.dfs.core.windows.net"
rutaSilver = f"abfss://silver@{storageLocation}.dfs.core.windows.net"
rutaGolden = f"abfss://golden@{storageLocation}.dfs.core.windows.net"

-- %% [markdown]
-- ### Eliminacion tablas Bronze

-- %%
-- DROP TABLES
DROP TABLE IF EXISTS 
{catalogo}.smartdata_proyect_bronze.genres;

-- DROP TABLES
DROP TABLE IF EXISTS 
{catalogo}.smartdata_proyect_bronze.languages;

-- DROP TABLES
DROP TABLE IF EXISTS 
{catalogo}.smartdata_proyect_bronze.movies;

-- DROP TABLES
DROP TABLE IF EXISTS 
{catalogo}.smartdata_proyect_bronze.movies_genres;

-- DROP TABLES
DROP TABLE IF EXISTS 
{catalogo}.smartdata_proyect_bronze.movies_languages;

-- %% [markdown]
-- ### Eliminando data RAW

-- %%
%python
## REMOVE DATA (Bronze)
dbutils.fs.rm(f"{rutaRaw}/2024-12-16", True)

-- %% [markdown]
-- ### Eliminacion tablas Silver

-- %%
-- DROP TABLES
DROP TABLE IF EXISTS 
{catalogo}.smartdata_proyect_silver.genres;

-- DROP TABLES
DROP TABLE IF EXISTS 
{catalogo}.smartdata_proyect_silver.languages;

-- DROP TABLES
DROP TABLE IF EXISTS 
{catalogo}.smartdata_proyect_silver.movies;

-- DROP TABLES
DROP TABLE IF EXISTS 
{catalogo}.smartdata_proyect_silver.movies_genres;

-- DROP TABLES
DROP TABLE IF EXISTS 
{catalogo}.smartdata_proyect_silver.movies_languages;

-- %% [markdown]
-- ### Eliminacion tablas Golden

-- %%
-- DROP TABLES
DROP TABLE IF EXISTS 
{catalogo}.smartdata_proyect_golden.results_movie_genre_languages;
