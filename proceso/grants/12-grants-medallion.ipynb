-- %% [markdown]
-- ##Grants

-- %%
GRANT SELECT ON TABLE smartdata_proyect_bronze.genres TO `data-engineer`;

-- %%
GRANT USE CATALOG ON CATALOG databricks_course_ws TO `data-engineer`;

-- %%
GRANT USE SCHEMA ON SCHEMA databricks_course_ws.smartdata_proyect_bronze TO `data-engineer`;
GRANT USE SCHEMA ON SCHEMA databricks_course_ws.smartdata_proyect_golden TO `data-engineer`;
GRANT USE SCHEMA ON SCHEMA databricks_course_ws.smartdata_proyect_silver TO `data-engineer`; 
GRANT CREATE ON SCHEMA databricks_course_ws.smartdata_proyect_bronze TO `data-engineer`;
GRANT CREATE ON SCHEMA databricks_course_ws.smartdata_proyect_golden TO `data-engineer`;
GRANT CREATE ON SCHEMA databricks_course_ws.smartdata_proyect_silver TO `data-engineer`;

-- %%
GRANT CREATE TABLE ON SCHEMA databricks_course_ws.smartdata_proyect_bronze TO `data-engineer`;
GRANT CREATE TABLE ON SCHEMA databricks_course_ws.smartdata_proyect_golden TO `data-engineer`;
GRANT CREATE TABLE ON SCHEMA databricks_course_ws.smartdata_proyect_silver TO `data-engineer`;

-- %%
GRANT SELECT ON SCHEMA databricks_course_ws.smartdata_proyect_bronze TO `data-engineer`;
GRANT SELECT ON SCHEMA databricks_course_ws.smartdata_proyect_golden TO `data-engineer`;
GRANT SELECT ON SCHEMA databricks_course_ws.smartdata_proyect_silver TO `data-engineer`;

-- %%
SHOW GRANTS ON SCHEMA databricks_course_ws.smartdata_proyect_bronze;

-- %%
SHOW GRANTS ON CATALOG databricks_course_ws;

-- %%
SHOW EXTERNAL LOCATIONS

-- %%
GRANT ALL PRIVILEGES
ON EXTERNAL LOCATION `external_location_bronze_lakehouse`
TO `data-engineer`;

GRANT ALL PRIVILEGES
ON EXTERNAL LOCATION `external_location_raw_lakehouse`
TO `data-engineer`;

GRANT ALL PRIVILEGES
ON EXTERNAL LOCATION `external_location_silver_lakehouse`
TO `data-engineer`;

GRANT ALL PRIVILEGES
ON EXTERNAL LOCATION `external_location_golden_lakehouse`
TO `data-engineer`;
