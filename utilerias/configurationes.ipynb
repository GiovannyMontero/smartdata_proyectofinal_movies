# %%
raw_folder_path = 'abfss://raw@azmedallonlakehouse.dfs.core.windows.net'
bronze_folder_path = 'abfss://bronze@azmedallonlakehouse.dfs.core.windows.net'
silver_folder_path = 'abfss://silver@azmedallonlakehouse.dfs.core.windows.net'
gold_folder_path = 'abfss://gold@azmedallonlakehouse.dfs.core.windows.net'
